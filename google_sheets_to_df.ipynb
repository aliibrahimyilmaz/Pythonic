# %%
import pandas as pd

# %%
file_url = "https://docs.google.com/spreadsheets/d/17G-0famIFGXDmLPHiMnoWnIhQox2MTCDS06vPgBpLzg/export?format=csv&?usp=sharing"
df = pd.read_csv(file_url, index_col="#")

# %%
df
# Out:
#       listing_date sale_or_rent          re_type      location         rooms  \
# #
# 1        10/3/2020      Satılık            Daire       Maltepe         2 + 1
# 2        10/5/2020      Satılık            Daire       Maltepe         3 + 1
# 3        8/17/2020      Satılık            Plaza      Ataşehir       6 Bölüm
# 4        10/9/2020      Satılık            Daire       Maltepe         2 + 1
# 5        10/9/2020      Satılık            Daire       Maltepe         2 + 1
# ...            ...          ...              ...           ...           ...
# 73676    9/30/2020      Satılık      Müstakil Ev      Bakırköy         4 + 1
# 73677    8/29/2020      Satılık            Tarla  Büyükçekmece  No room data
# 73678    9/28/2020      Kiralık  Dükkan & Mağaza  Bahçelievler       2 Bölüm
# 73679     9/1/2020      Satılık    Muhtelif Arsa        Beykoz  No room data
# 73680    6/18/2020      Kiralık             Ofis      Beşiktaş       2 Bölüm
#
# ...
